# %% [markdown]
# ![cropped-Recurso-2-2.png](attachment:cropped-Recurso-2-2.png)
# ### Curso: Big Data
# #### Control I - Analisis de grandes volumenes de datos en Python
# #### Profesor: Diego Miranda
# #### Data Scientist

# %% [markdown]
# ### Dado los datasets: 'Dataset1.csv' y 'Dataset2.xlsx' se pide:
# 1) Unir los Datasets mediante la funcion merge (2 puntos)
# 2) Realizar un analisis exploratorio de datos utilizando al menos 5 comandos (5 puntos)
# 3) Crear una variable dummy para la columna estado_civil (2 puntos)
# 4) Imputar los valores perdidos en las columnas que correspondan (5 puntos)
# 5) Crear una funcion en la columna 'saldo_bancario', con el objetivo de clasificar los clientes segun su saldo en bajo, medio, alto (3 puntos)
# 6) Eliminar outliers de la columna 'age' mediante el metodo recorrido intercuartil (3 puntos)
# 7) Realizar al menos 2 graficos utilizando la libreria plotly (2 puntos)
